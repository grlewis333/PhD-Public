# %%
import seabreeze
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
from seabreeze.spectrometers import Spectrometer
spec = Spectrometer.from_first_available()
spec
# Out:
# <Spectrometer USB4000:FLMT01856>

# %%
spec.integration_time_micros(1000000)

# %%
wavelengths = spec.wavelengths()
wavelengths
# Out:
# array([528.4295    , 528.52212501, 528.6147435 , ..., 816.2294228 ,
#        816.29293044, 816.35642864])

# %%
intensities = spec.intensities()
intensities
# Out:
# array([2881.49203125, 2918.35546875, 2863.0603125 , ..., 4810.67859375,
#        4810.67859375, 4810.67859375])

# %%
plt.plot(wavelengths,intensities)

plt.xlabel('Wavelength / nm')
plt.ylabel('Intensity / a.u.')
# Out:
# Text(0, 0.5, 'Intensity / a.u.')
